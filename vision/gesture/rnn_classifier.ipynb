# %%
import keras
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, LSTM, Flatten, BatchNormalization, TimeDistributed, Activation
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np

# %%
X = np.load("gesture_data/x.npy")
y = np.load("gesture_data/y.npy")

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 4)

# %%
x_train = keras.utils.normalize(x_train, axis = 1)
x_test = keras.utils.normalize(x_test, axis = 1)
print(x_train.shape)
print(x_test.shape)
# Out:
# (142, 67, 3)
# (36, 67, 3)

# %%
epochs = 200
batch_size = 67
_dropout = 0.5
_activation='relu'
_optimizer='adam'

# %%
input_shape = x_train.shape[1], x_train.shape[2]
model = Sequential()
model.add(LSTM(128, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(128, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(64, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(32, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(TimeDistributed(Dense(3))) 

model.add(Flatten())
model.add(Dense(y_train.shape[1], activation = tf.nn.softmax))
model.add(Activation('relu'))

# model.add(TimeDistributed(Dense(128, input_shape = input_shape)))
# myOptimizer = Adam(lr = 0.001) 
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['categorical_accuracy'])

# model.add(Flatten())
# model.add(Dense(128, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(Dense(128, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(BatchNormalization())
# model.add(Dense(64, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(BatchNormalization())
# model.add(Dense(32, activation = tf.nn.relu))
# model.add(BatchNormalization())
# model.add(Dense(y_train.shape[1], activation = tf.nn.softmax))

# model.add(Flatten())
# model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
# # model.add(Dropout(0.5))
# # model.add(Dense(128, activation='relu'))
# # model.add(Dropout(0.5))
# # model.add(Dense(y_train.shape[1], activation='softmax'))
model.compile(optimizer='Adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])
model.fit(x_train, y_train, epochs=200,batch_size=67)
model.summary()
# model.compile(loss = 'categorical_crossentropy', optimizer = _optimizer, metrics=['accuracy'])


#     model = Sequential()
#     model.add(TimeDistributed(Dense(X_vector_dim, activation=_activation), input_shape=input_shape))
#     
#     model.add(TimeDistributed(Dense(X_vector_dim*2, activation=_activation))) #(5, 80)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim, activation=_activation))) #(5, 40)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim/2, activation=_activation))) #(5, 20)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim/4, activation=_activation))) #(5, 10)
#     model.add(Dropout(_dropout))
#     model.add(LSTM(X_vector_dim/4, dropout=_dropout, recurrent_dropout=_dropout))
#     model.add(Dense(y_vector_dim,activation='softmax'))
#     model.compile(loss='categorical_crossentropy', optimizer=_optimizer, metrics=['accuracy'])
#     model.summary()

# # Fit model
# print('Training...')
# model.fit(x_train, y_train,
#          batch_size=batch_size,
#          epochs=epochs,
#          validation_data=(x_test, y_test))
# # Evaluate Model and Predict Classes
# print('Testing...')
score, accuracy = model.evaluate(x_test, y_test,
                                batch_size=67)

print('Test score: {:.3}'.format(score))
print('Test accuracy: {:.3}'.format(accuracy))
# Out:
# Epoch 1/200
# 142/142 [==============================] - 5s 38ms/step - loss: 1.8297 - acc: 0.3944
# Epoch 2/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.6807 - acc: 0.4155
# Epoch 3/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.4242 - acc: 0.5070
# Epoch 4/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.3501 - acc: 0.4789
# Epoch 5/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.2222 - acc: 0.5352
# Epoch 6/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.1317 - acc: 0.5563
# Epoch 7/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.2388 - acc: 0.5000
# Epoch 8/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.0352 - acc: 0.6268
# Epoch 9/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.8427 - acc: 0.6690
# Epoch 10/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6927 - acc: 0.7254
# Epoch 11/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6571 - acc: 0.7535
# Epoch 12/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7054 - acc: 0.7254
# Epoch 13/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7288 - acc: 0.7465
# Epoch 14/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7055 - acc: 0.7465
# Epoch 15/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.5896 - acc: 0.8028
# Epoch 16/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.5188 - acc: 0.7887
# Epoch 17/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4683 - acc: 0.8451
# Epoch 18/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4292 - acc: 0.8310
# Epoch 19/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4579 - acc: 0.8239
# Epoch 20/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4055 - acc: 0.8169
# Epoch 21/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3561 - acc: 0.8662
# Epoch 22/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3234 - acc: 0.8592
# Epoch 23/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4347 - acc: 0.8099
# Epoch 24/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3776 - acc: 0.8732
# Epoch 25/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3415 - acc: 0.8521
# Epoch 26/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3660 - acc: 0.8451
# Epoch 27/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4060 - acc: 0.8310
# Epoch 28/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.2728 - acc: 0.8873
# Epoch 29/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4212 - acc: 0.8239
# Epoch 30/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.2960 - acc: 0.8592
# Epoch 31/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.4106 - acc: 0.8592
# Epoch 32/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3018 - acc: 0.8944
# Epoch 33/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.3028 - acc: 0.8662
# Epoch 34/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.2477 - acc: 0.8944
# Epoch 35/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0
200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.1064 - acc: 0.9648
# Epoch 163/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0499 - acc: 0.9789
# Epoch 164/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0525 - acc: 0.9789
# Epoch 165/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0602 - acc: 0.9789
# Epoch 166/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0291 - acc: 0.9930
# Epoch 167/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0361 - acc: 0.9859
# Epoch 168/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0607 - acc: 0.9718
# Epoch 169/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0365 - acc: 0.9789
# Epoch 170/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0549 - acc: 0.9718
# Epoch 171/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0405 - acc: 0.9859
# Epoch 172/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0104 - acc: 1.0000
# Epoch 173/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0624 - acc: 0.9859
# Epoch 174/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0180 - acc: 0.9930
# Epoch 175/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0509 - acc: 0.9789
# Epoch 176/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0824 - acc: 0.9577
# Epoch 177/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0705 - acc: 0.9789
# Epoch 178/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0596 - acc: 0.9718
# Epoch 179/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0306 - acc: 0.9930
# Epoch 180/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0788 - acc: 0.9789
# Epoch 181/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0354 - acc: 0.9930
# Epoch 182/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.1001 - acc: 0.9648
# Epoch 183/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.1656 - acc: 0.9437
# Epoch 184/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.1051 - acc: 0.9507
# Epoch 185/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0408 - acc: 0.9859
# Epoch 186/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0853 - acc: 0.9577
# Epoch 187/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0911 - acc: 0.9577
# Epoch 188/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0652 - acc: 0.9718
# Epoch 189/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0876 - acc: 0.9577
# Epoch 190/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0966 - acc: 0.9718
# Epoch 191/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0342 - acc: 0.9859
# Epoch 192/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0814 - acc: 0.9507
# Epoch 193/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0430 - acc: 0.9859
# Epoch 194/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0597 - acc: 0.9718
# Epoch 195/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0419 - acc: 0.9930
# Epoch 196/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0277 - acc: 0.9930
# Epoch 197/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0470 - acc: 0.9789
# Epoch 198/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0197 - acc: 0.9930
# Epoch 199/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0310 - acc: 0.9859
# Epoch 200/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.0151 - acc: 1.0000
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 67, 128)           67584
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 67, 128)           0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 67, 128)           512
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 67, 128)           131584
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 67, 128)           0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 67, 128)           512
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 67, 64)            49408
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 67, 64)            0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 67, 64)            256
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 67, 32)            12416
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 67, 32)            0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 67, 32)            128
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 67, 3)             99
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 201)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 606
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 263,105
# Trainable params: 262,401
# Non-trainable params: 704
# _________________________________________________________________
# 36/36 [==============================] - 2s 42ms/step
# Test score: 0.364
# Test accuracy: 0.944

# %%
model.save('gesture_data/pointing.h5')

# %%
model1 = load_model('gesture_data/pointing.h5')
score, accuracy = model1.evaluate(x_test, y_test,
                                batch_size=67)

print('Test score: {:.3}'.format(score))
print('Test accuracy: {:.3}'.format(accuracy))
# Out:
# 36/36 [==============================] - 2s 58ms/step
# Test score: 0.364
# Test accuracy: 0.944
