# %%
import keras
from keras.models import Sequential, load_model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, LSTM, Flatten, BatchNormalization, TimeDistributed, Activation
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np

# %%
X = np.load("gesture_data/x.npy")
y = np.load("gesture_data/y.npy")

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 4)

# %%
x_train = keras.utils.normalize(x_train, axis = 1)
x_test = keras.utils.normalize(x_test, axis = 1)
print(x_train.shape)
print(x_test.shape)
# Out:
# (83, 46, 3)
# (21, 46, 3)

# %%
epochs = 200
batch_size = 46
_dropout = 0.5
_activation='relu'
_optimizer='adam'

# %%
input_shape = x_train.shape[1], x_train.shape[2]
model = Sequential()
model.add(LSTM(128, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(128, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(64, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(LSTM(32, input_shape=input_shape, return_sequences = True))
model.add(Dropout(0.5))                             
model.add(BatchNormalization())

model.add(TimeDistributed(Dense(3))) 

model.add(Flatten())
model.add(Dense(y_train.shape[1], activation = tf.nn.softmax))
model.add(Activation('relu'))

# model.add(TimeDistributed(Dense(128, input_shape = input_shape)))
# myOptimizer = Adam(lr = 0.001) 
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['categorical_accuracy'])

# model.add(Flatten())
# model.add(Dense(128, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(Dense(128, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(BatchNormalization())
# model.add(Dense(64, activation = tf.nn.relu))
# model.add(Dropout(_dropout))
# model.add(BatchNormalization())
# model.add(Dense(32, activation = tf.nn.relu))
# model.add(BatchNormalization())
# model.add(Dense(y_train.shape[1], activation = tf.nn.softmax))

# model.add(Flatten())
# model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
# # model.add(Dropout(0.5))
# # model.add(Dense(128, activation='relu'))
# # model.add(Dropout(0.5))
# # model.add(Dense(y_train.shape[1], activation='softmax'))
model.compile(optimizer='Adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])
model.fit(x_train, y_train, epochs=200,batch_size=46)
model.summary()
# model.compile(loss = 'categorical_crossentropy', optimizer = _optimizer, metrics=['accuracy'])


#     model = Sequential()
#     model.add(TimeDistributed(Dense(X_vector_dim, activation=_activation), input_shape=input_shape))
#     
#     model.add(TimeDistributed(Dense(X_vector_dim*2, activation=_activation))) #(5, 80)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim, activation=_activation))) #(5, 40)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim/2, activation=_activation))) #(5, 20)
#     model.add(Dropout(_dropout))
#     model.add(TimeDistributed(Dense(X_vector_dim/4, activation=_activation))) #(5, 10)
#     model.add(Dropout(_dropout))
#     model.add(LSTM(X_vector_dim/4, dropout=_dropout, recurrent_dropout=_dropout))
#     model.add(Dense(y_vector_dim,activation='softmax'))
#     model.compile(loss='categorical_crossentropy', optimizer=_optimizer, metrics=['accuracy'])
#     model.summary()

# # Fit model
# print('Training...')
# model.fit(x_train, y_train,
#          batch_size=batch_size,
#          epochs=epochs,
#          validation_data=(x_test, y_test))
# # Evaluate Model and Predict Classes
200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0131 - acc: 1.0000
# Epoch 148/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0164 - acc: 0.9880
# Epoch 149/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0498 - acc: 0.9880
# Epoch 150/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0517 - acc: 0.9759
# Epoch 151/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0135 - acc: 1.0000
# Epoch 152/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0387 - acc: 0.9759
# Epoch 153/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0459 - acc: 0.9880
# Epoch 154/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0175 - acc: 0.9880
# Epoch 155/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0144 - acc: 0.9880
# Epoch 156/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0144 - acc: 0.9880
# Epoch 157/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0216 - acc: 0.9880
# Epoch 158/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0170 - acc: 1.0000
# Epoch 159/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0487 - acc: 0.9880
# Epoch 160/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0229 - acc: 0.9880
# Epoch 161/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0311 - acc: 0.9759
# Epoch 162/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0065 - acc: 1.0000
# Epoch 163/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0060 - acc: 1.0000
# Epoch 164/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0133 - acc: 1.0000
# Epoch 165/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0040 - acc: 1.0000
# Epoch 166/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0762 - acc: 0.9759
# Epoch 167/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0314 - acc: 0.9880
# Epoch 168/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0114 - acc: 1.0000
# Epoch 169/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0620 - acc: 0.9880
# Epoch 170/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0235 - acc: 0.9880
# Epoch 171/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0116 - acc: 1.0000
# Epoch 172/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0074 - acc: 1.0000
# Epoch 173/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0145 - acc: 0.9880
# Epoch 174/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0213 - acc: 0.9880
# Epoch 175/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0166 - acc: 0.9880
# Epoch 176/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0019 - acc: 1.0000
# Epoch 177/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0190 - acc: 0.9880
# Epoch 178/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0590 - acc: 0.9880
# Epoch 179/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0066 - acc: 1.0000
# Epoch 180/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0745 - acc: 0.9518
# Epoch 181/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0230 - acc: 0.9880
# Epoch 182/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.1305 - acc: 0.9639
# Epoch 183/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0137 - acc: 1.0000
# Epoch 184/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0348 - acc: 0.9759
# Epoch 185/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0088 - acc: 1.0000
# Epoch 186/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0271 - acc: 0.9880
# Epoch 187/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0796 - acc: 0.9880
# Epoch 188/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0634 - acc: 0.9759
# Epoch 189/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0214 - acc: 0.9880
# Epoch 190/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0049 - acc: 1.0000
# Epoch 191/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0465 - acc: 0.9759
# Epoch 192/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0465 - acc: 0.9880
# Epoch 193/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0276 - acc: 0.9880
# Epoch 194/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0239 - acc: 0.9880
# Epoch 195/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.1335 - acc: 0.9759
# Epoch 196/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0379 - acc: 0.9639
# Epoch 197/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0158 - acc: 1.0000
# Epoch 198/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0507 - acc: 0.9880
# Epoch 199/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0116 - acc: 1.0000
# Epoch 200/200
# 83/83 [==============================] - 0s 3ms/step - loss: 0.0613 - acc: 0.9759
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 46, 128)           67584
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 46, 128)           0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 46, 128)           512
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 46, 128)           131584
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 46, 128)           0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 46, 128)           512
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 46, 64)            49408
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 46, 64)            0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 46, 64)            256
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 46, 32)            12416
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 46, 32)            0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 46, 32)            128
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 46, 3)             99
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 138)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 417
# _________________________________________________________________
# activation_7 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 262,916
# Trainable params: 262,212
# Non-trainable params: 704
# _________________________________________________________________
# 21/21 [==============================] - 1s 70ms/step
# Test score: 1.57
# Test accuracy: 0.81

# %%
model.save('gesture_data/pointing.h5')

# %%
model1 = score, accuracy = model.evaluate(x_test, y_test,
                                batch_size=46)

print('Test score: {:.3}'.format(score))
print('Test accuracy: {:.3}'.format(accuracy))
